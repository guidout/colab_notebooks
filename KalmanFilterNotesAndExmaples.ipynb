# %% [markdown]
# <a href="https://colab.research.google.com/github/guidout/colab_notebooks/blob/main/KalmanFilterNotesAndExmaples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# At the time n, the estimate x^n,n would be the average of all previous measurements
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)where
# Example Notation:
# x	is the true value of the weight
# zn	is the measured value of the weight at time n
# x^n,n	is the estimate of x at time n (the estimate is made after taking the measurement zn )
# x^n+1,n	is the estimate of the future state (n+1 ) of x. The estimate is made at the time n. In other words, x^n+1,n is a predicted state or extrapolated state
# x^n−1,n−1	is the estimate of x at time n−1 (the estimate is made after taking the measurement zn−1 )
# x^n,n−1	is the previous prediction - the estimate of the state at time n. The estimate is made at the time n−1
